# %% [markdown]
# ### aaa
# - torch.no_grad()
#     - 定义了一个上下文管理器，隐式地不进行梯度更新，不会改变requires_grad
#     - 适用于eval阶段，或model forward中某些不更新梯度的模块
#     - 不存储梯度
# - requires_grad
#     - 显示地frozen 掉一些module 的梯度更新
#     - layer/module级别
#     - 更灵活
#     - 仅仅使得梯度失效

# %% [markdown]
# *aaa*
# aaa
# - [ ] 待办事项
# - [x] 已完成任务
# [Google](https://www.google.com)

# %% [markdown]
# ```python
# def print_hello():
#     print("hello")
# ```

# %% [markdown]
# ```C++
# #include<stdio.h>
# #define a 12
# printf("hello world\n");
# ```

# %% [markdown]
# aaa
# > 这是引用
# ___
# shangmian shi fenge xian

# %% [markdown]
# - [ ] 待办事项
# - [x] 已完成任务
